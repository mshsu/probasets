# %% [markdown]
# <a href="https://colab.research.google.com/github/mshsu/probasets/blob/main/lognormal_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lognormal Demo
#
# The lognormal distribution can be used to model all kinds of phenomena. What kinds of data are lognormally distributed?
#
# *For all data, we will remove values equal to 0.

# %% [markdown]
# ## Setup

# %%
# !pip install symbulate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting symbulate
#   Downloading symbulate-0.5.7-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from symbulate) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from symbulate) (1.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from symbulate) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->symbulate) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->symbulate) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->symbulate) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->symbulate) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->symbulate) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->symbulate) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->symbulate) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->symbulate) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->symbulate) (1.16.0)
# Installing collected packages: symbulate
# Successfully installed symbulate-0.5.7

# %%
import pandas as pd
import requests
import numpy as np
import time
from symbulate import *

# %%
url = "https://mshsu.github.io/probasets/data/"

# %% [markdown]
# ## Stack Overflow Comment Length

# %% [markdown]
# The length of internet comments tends to follow a lognormal distribution. Stack Overflow is a good example of this. More information about the data [here](https://cloud.google.com/blog/topics/public-datasets/google-bigquery-public-datasets-now-include-stack-overflow-q-a).

# %%
stacko = pd.read_csv(url + "StackOverflow.csv")
stacko
# Out:
#           id                                               text  \
# 0    1985362                      `return memcmp(a, b, 4) < 0;`
# 1    1992048  ok - thanks, that helped. i could easily contr...
# 2    1993240  In fact, C++ does this with the specialised co...
# 3    1993904          None. And they are not function pointers.
# 4    1995764  It's undefined because the C++ Standard says i...
# ..       ...                                                ...
# 995  2021162  Awesome, i got you, but how do i define these ...
# 996  2021181  @GMan: Right, platform-specific and you can st...
# 997  2021186  My suspicion, which you'll be able to confirm ...
# 998  2021199  @roy do I have to make another private static ...
# 999  2021290                     @Jerry: and has integral type.
#
#                       creation_date  post_id  user_id user_display_name  score
# 0    2010-01-13 15:16:02.610000 UTC  2057610      NaN        Roger Pate     18
# 1    2010-01-14 11:12:43.377000 UTC  2063271      NaN        user250608      6
# 2    2010-01-14 14:23:44.740000 UTC  2064645      NaN              anon      9
# 3    2010-01-14 15:38:19.520000 UTC  2065232      NaN              anon      9
# 4    2010-01-14 19:13:56.650000 UTC  2065961      NaN              anon      6
# ..                              ...      ...      ...               ...    ...
# 995  2010-01-18 20:17:03.060000 UTC  2087739      NaN        user222427      0
# 996  2010-01-18 20:18:33.317000 UTC  2088562      NaN        Roger Pate      0
# 997  2010-01-18 20:19:01.570000 UTC  2087500      NaN          user8599      0
# 998  2010-01-18 20:20:12.037000 UTC  2087739      NaN        user222427      0
# 999  2010-01-18 20:31:35.190000 UTC  2088964      NaN        Roger Pate      0
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### Distribution of Comment Length

# %%
stacko_transf = np.log(stacko['text'].str.len())
stacko_mean = stacko_transf.mean()
stacko_sd = stacko_transf.std()

# %%
stacko['text'].str.len().plot.hist(density=True)
LogNormal(stacko_mean, stacko_sd).plot()

# %% [markdown]
# ### Distribution of log(Comment Length)

# %%
stacko_transf.plot.hist(density=True)
Normal(stacko_mean, stacko_sd).plot()

# %% [markdown]
# ## US Cities Population

# %% [markdown]
# US City populations appear to be lognormally distributed as well. (Because the distribution of city populations is so heavily right skew, the untransformed distribution is not shown.) More information about the data [here](https://simplemaps.com/data/us-cities).

# %%
cities = pd.read_csv(url + "Cities.csv")
cities = cities[cities['population'] > 0]
cities
# Out:
#               city   city_ascii state_id  state_name  county_fips  \
# 0         New York     New York       NY    New York        36081
# 1      Los Angeles  Los Angeles       CA  California         6037
# 2          Chicago      Chicago       IL    Illinois        17031
# 3            Miami        Miami       FL     Florida        12086
# 4           Dallas       Dallas       TX       Texas        48113
# ...            ...          ...      ...         ...          ...
# 30378       Lupton       Lupton       AZ     Arizona         4001
# 30379    Goldcreek    Goldcreek       MT     Montana        30077
# 30380    The Ranch    The Ranch       MN   Minnesota        27087
# 30381   Stotesbury   Stotesbury       MO    Missouri        29217
# 30382        Kelly        Kelly       KS      Kansas        20131
#
#        county_name      lat       lng  population  density source  military  \
# 0           Queens  40.6943  -73.9249    18972871  10768.2  shape     False
# 1      Los Angeles  34.1141 -118.4068    12121244   3267.6  shape     False
# 2             Cook  41.8375  -87.6866     8595181   4576.6  shape     False
# 3       Miami-Dade  25.7840  -80.2101     5711945   4945.7  shape     False
# 4           Dallas  32.7935  -96.7667     5668165   1522.2  shape     False
# ...            ...      ...       ...         ...      ...    ...       ...
# 30378       Apache  35.3547 -109.0527           1     24.5  shape     False
# 30379       Powell  46.5838 -112.9284           1      1.9  shape     False
# 30380     Mahnomen  47.3198  -95.6952           1     11.4  shape     False
# 30381       Vernon  37.9744  -94.5645           1     25.2  shape     False
# 30382       Nemaha  39.7368  -96.0008           1     35.7  shape     False
#
#        incorporated             timezone  ranking  \
# 0              True     America/New_York        1
# 1              True  America/Los_Angeles        1
# 2              True      America/Chicago        1
# 3              True     America/New_York        1
# 4              True      America/Chicago        1
# ...             ...                  ...      ...
# 30378         False       America/Denver        3
# 30379         False       America/Denver        3
# 30380          True      America/Chicago        4
# 30381          True      America/Chicago        3
# 30382         False      America/Chicago        3
#
#                                                     zips          id
# 0      11229 11226 11225 11224 11223 11221 11220 1138...  1840034016
# 1      90291 90293 90292 91316 91311 90035 90034 9003...  1840020491
# 2      60018 60649 60641 60640 60643 60642 60645 6064...  1840000494
# 3      33128 33129 33125 33126 33127 33149 33144 3314...  1840015149
# 4      75287 75098 75234 75254 75251 75252 75253 7503...  1840019440
# ...                                                  ...         ...
# 30378                                              86508  1840022623
# 30379                                              59733  1840032724
# 30380                                              56557  1840039629
# 30381                                              64752  1840010843
# 30382                                              66538  1840030166
#
# [30383 rows x 17 columns]

# %%
cities_transf = np.log(cities['population'])
cities_mean = cities_transf.mean()
cities_sd = cities_transf.std()

# %% [markdown]
# ### Distribution of log(City Population)

# %%
cities_transf.plot.hist(density=True, bins=20)
Normal(cities_mean, cities_sd).plot()

# %% [markdown]
# ## COVID Hospital Utilization

# %% [markdown]
# The Center for Medicare and Medicaid (CMS) keeps weekly data on nursing homes that treat COVID. From this data, we can find that many variables regarding hospital utilization follow a lognormal distribution, including:
# - Weekly Number of Occupied Beds per Hospital
# - Total Resident COVID Deaths per Hospital
#
# More information about the data [here](https://data.cms.gov/covid-19/covid-19-nursing-home-data). The data have been subset down to a single week, with hospitals only from New York.

# %%
hosp = pd.read_csv(url + "COVIDHospitals.csv")
hosp
# Out:
#     Week Ending Federal Provider Number  \
# 0      3/7/2021                  335864
# 1      3/7/2021                  335856
# 2      3/7/2021                  335869
# 3      3/7/2021                  335853
# 4      3/7/2021                  335862
# ..          ...                     ...
# 611    3/7/2021                  335091
# 612    3/7/2021                  335188
# 613    3/7/2021                  335374
# 614    3/7/2021                  335380
# 615    3/7/2021                  335663
#
#                                          Provider Name  \
# 0               FLUSHING HOSPITAL MEDICAL CENTER T C U
# 1                JAMAICA HOSPITAL MEDICAL CENTER T C U
# 2                  NORTHERN WESTCHESTER HOSPITAL T C U
# 3                    JOHN T MATHER MEMORIAL HOSP T C U
# 4                 NEW YORK-PRESBYTERIAN / QUEENS T C U
# ..                                                 ...
# 611    FULTON CENTER FOR REHABILITATION AND HEALTHCARE
# 612    NEW PALTZ CENTER FOR REHABILITATION AND NURSING
# 613    THE PINES AT UTICA CENTER FOR NURSING AND REHAB
# 614  NORTHERN METROPOLITAN RES HEALTH CARE FACILITY...
# 615          SAFIRE REHABILITATION OF SOUTHTOWN, L L C
#
#                       Provider Address   Provider City Provider State  \
# 0    45TH AVENUE AND PARSONS BOULEVARD        FLUSHING             NY
# 1             8900 VAN WYCK EXPRESSWAY         JAMAICA             NY
# 2                 400 EAST MAIN STREET     MOUNT KISCO             NY
# 3                75 NORTH COUNTRY ROAD  PORT JEFFERSON             NY
# 4                    56-45 MAIN STREET        FLUSHING             NY
# ..                                 ...             ...            ...
# 611            847 COUNTY  HIGHWAY 122    GLOVERSVILLE             NY
# 612                      1 JANSEN ROAD       NEW PALTZ             NY
# 613               1800 BUTTERFIELD AVE           UTICA             NY
# 614                   225 MAPLE AVENUE          MONSEY             NY
# 615                300 DORRANCE AVENUE         BUFFALO             NY
#
#      Provider Zip Code  Provider Phone Number       County Submitted Data  \
# 0                11355             7182066595       Queens              Y
# 1                11418             7182066595       Queens              Y
# 2                10549             9146668306  Westchester              Y
# 3                11777             6314731320      Suffolk              Y
# 4                11355             9999999991       Queens              Y
# ..                 ...                    ...          ...            ...
# 611              12078             5187733400       Fulton              Y
# 612              12561             8452550830       Ulster              Y
# 613              13501             3157973570       Oneida              N
# 614              10952             8453529000     Rockland              Y
# 615              14220             7165665252         Erie              N
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 611  ...
# 612  ...
# 613  ...
# 614  ...
# 615  ...
#
#     Percentage of Current Residents Up to Date with COVID-19 Vaccines with No Medical Contraindications  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 611                                                NaN
# 612                                                NaN
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
#
#      Percentage of Current Residents with a Completed Vaccination Up to Date with COVID-19 Vaccines  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 611                                                NaN
# 612                                                NaN
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
#
#      Number of Healthcare Personnel with a Completed Vaccination Eligible to Work in this Facility for At Least 1 Day This Week who Received a COVID-19 Vaccine Booster at Any Time  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 611                                                NaN
# 612                                                NaN
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
#
#      Recent Percentage of Current Healthcare Personnel with a Completed Vaccination who Received a COVID-19 Vaccine Booster at Any Time  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 611                                                NaN
# 612                                                NaN
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
#
#      Percentage of Current Healthcare Personnel with a Completed Vaccination who Received a COVID-19 Vaccine Booster at Any Time  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 611                                                NaN
# 612                                                NaN
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
#
#      Number of Healthcare Personnel Eligible to Work in this Facility for At Least 1 Day This Week Up to Date with COVID-19 Vaccines  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 611                                                NaN
# 612                                                NaN
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
#
#      Recent Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 611                                                NaN
# 612                                                NaN
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
#
#      Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 611                                                NaN
# 612                                                NaN
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
#
#      Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines with No Medical Contraindications  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 611                                                NaN
# 612                                                NaN
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
#
#      Percentage of Current Healthcare Personnel with a Completed Vaccination Up to Date with COVID-19 Vaccines
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 611                                                NaN
# 612                                                NaN
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
#
# [616 rows x 121 columns]

# %% [markdown]
# ### Distribution of Number of Occupied Beds, for NY Nursing Facilities the Week Ending 3/7/2021

# %%
beds = hosp[hosp['Total Number of Occupied Beds'] > 0]['Total Number of Occupied Beds']
beds_transf = np.log(beds)
beds_mean = beds_transf.mean()
beds_sd = beds_transf.std()

# %%
beds.plot.hist(density=True, bins=20)
LogNormal(beds_mean, beds_sd).plot()

# %% [markdown]
# ### Distribution of log(Number of Occupied Beds), for for NY Nursing Facilities the Week Ending 3/7/2021

# %%
beds_transf.plot.hist(density=True, bins=20)
Normal(beds_mean, beds_sd).plot()

# %% [markdown]
# ### Distribution of Residents Total Deaths, for for NY Nursing Facilities the Week Ending 3/7/2021

# %%
deaths = hosp['Residents Total All Deaths'][hosp['Residents Total All Deaths'] > 0]
deaths_transf = np.log(deaths)
deaths_mean = deaths_transf.mean()
deaths_sd = deaths_transf.std()

# %%
deaths.plot.hist(density=True, bins=20)
LogNormal(deaths_mean, deaths_sd).plot()

# %% [markdown]
# ### Distribution of log(Residents Total Deaths), for for NY Nursing Facilities the Week Ending 3/7/2021

# %%
deaths_transf.plot.hist(density=True)
Normal(deaths_mean, deaths_sd).plot()
